# %%
import pandas as pd

#The dataset is a financial time-series dataset containing stock price information. 
#It consists of 7 columns representing the daily trading activity for a specific asset over a period. 
#The structure includes temporal data (Date), price movements (Open, High, Low, Close, Adj Close), and market activity volume (Volume).

# Load the dataset
df = pd.read_csv('/Users/earltavera/Desktop/MSE803/Week 2/A1/beijing+multi+site+air+quality+data/data.csv')

# Display the first 5 rows
print("First 5 rows of the dataset:")
print(df.head())

# Identify column names and data types
print("\nColumn names and data types:")
print(df.dtypes)

# Count total rows and columns
rows, cols = df.shape
print(f"\nTotal rows: {rows}")
print(f"Total columns: {cols}")
# Out:
# First 5 rows of the dataset:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-07-02  183.820007  187.300003  183.419998  187.179993  182.199005
# 1  2018-07-03  187.789993  187.949997  183.539993  183.919998  179.025772
# 2  2018-07-05  185.259995  186.410004  184.279999  185.399994  180.466370
# 3  2018-07-06  185.419998  188.429993  185.199997  187.970001  182.967972
# 4  2018-07-09  189.500000  190.679993  189.300003  190.580002  185.508545
#
#      Volume
# 0  17731300
# 1  13954800
# 2  16604200
# 3  17485200
# 4  19756600
#
# Column names and data types:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object
#
# Total rows: 503
# Total columns: 7
